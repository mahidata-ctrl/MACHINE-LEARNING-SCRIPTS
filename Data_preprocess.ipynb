# %%
import pandas as pd

# %%
df=pd.read_csv("data_clean (1).csv")

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.shape
# Out:
# (158, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
df["Ozone"].unique()
# Out:
# array([ 41.,  36.,  12.,  18.,  nan,  28.,  23.,  19.,   8.,   7.,  16.,
#         11.,  14.,  34.,   6.,  30.,   1.,   4.,  32.,  45., 115.,  37.,
#         29.,  71.,  39.,  21.,  20.,  13., 135.,  49.,  64.,  40.,  77.,
#         97.,  85.,  10.,  27.,  48.,  35.,  61.,  79.,  63.,  80., 108.,
#         52.,  82.,  50.,  59.,   9.,  78.,  66., 122.,  89., 110.,  44.,
#         65.,  22.,  31., 168.,  73.,  76., 118.,  84.,  96.,  91.,  47.,
#         24.,  46.])

# %%
df["Ozone"].mean()
# Out:
# 41.583333333333336

# %%
df["Ozone"]=df["Ozone"].fillna(df["Ozone"].mean())
df
# Out:
#      Unnamed: 0      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp  \
# 0             1  41.000000    190.0   7.4     67     5    1  2010    67
# 1             2  36.000000    118.0   8.0     72     5    2  2010    72
# 2             3  12.000000    149.0  12.6     74     5    3  2010    74
# 3             4  18.000000    313.0  11.5     62     5    4  2010    62
# 4             5  41.583333      NaN  14.3     56     5    5  2010    56
# ..          ...        ...      ...   ...    ...   ...  ...   ...   ...
# 153         154  41.000000    190.0   7.4     67     5    1  2010    67
# 154         155  30.000000    193.0   6.9     70     9   26  2010    70
# 155         156  41.583333    145.0  13.2     77     9   27  2010    77
# 156         157  14.000000    191.0  14.3     75     9   28  2010    75
# 157         158  18.000000    131.0   8.0     76     9   29  2010    76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 10 columns]

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#          Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.000000    190.0   7.4     67     5    1  2010    67       S
# 1    36.000000    118.0   8.0     72     5    2  2010    72       C
# 2    12.000000    149.0  12.6     74     5    3  2010    74      PS
# 3    18.000000    313.0  11.5     62     5    4  2010    62       S
# 4    41.583333      NaN  14.3     56     5    5  2010    56       S
# ..         ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153  41.000000    190.0   7.4     67     5    1  2010    67       C
# 154  30.000000    193.0   6.9     70     9   26  2010    70      PS
# 155  41.583333    145.0  13.2     77     9   27  2010    77       S
# 156  14.000000    191.0  14.3     75     9   28  2010    75       S
# 157  18.000000    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df["Solar.R"].unique()
# Out:
# array([190., 118., 149., 313.,  nan, 299.,  99.,  19., 194., 256., 290.,
#        274.,  65., 334., 307.,  78., 322.,  44.,   8., 320.,  25.,  92.,
#         66., 266.,  13., 252., 223., 279., 286., 287., 242., 186., 220.,
#        264., 127., 273., 291., 323., 259., 250., 148., 332., 191., 284.,
#         37., 120., 137., 150.,  59.,  91., 135.,  47.,  98.,  31., 138.,
#        269., 248., 236., 101., 175., 314., 276., 267., 272., 139.,  48.,
#        260., 285., 187.,   7., 258., 295., 294.,  81.,  82., 213., 275.,
#        253., 254.,  83.,  24.,  77., 255., 229., 207., 222., 192., 157.,
#         64.,  71.,  51., 115., 244.,  36., 212., 238., 215., 153., 203.,
#        225., 237., 188., 167., 197., 183., 189.,  95., 230., 112., 224.,
#         27., 201.,  14.,  49.,  20., 193., 145., 131.])

# %%
df["Solar.R"].mean()
# Out:
# 185.40397350993376

# %%
df["Solar.R"]=df["Solar.R"].fillna(df["Solar.R"].mean())
df
# Out:
#          Ozone     Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4     67     5    1  2010    67       S
# 1    36.000000  118.000000   8.0     72     5    2  2010    72       C
# 2    12.000000  149.000000  12.6     74     5    3  2010    74      PS
# 3    18.000000  313.000000  11.5     62     5    4  2010    62       S
# 4    41.583333  185.403974  14.3     56     5    5  2010    56       S
# ..         ...         ...   ...    ...   ...  ...   ...   ...     ...
# 153  41.000000  190.000000   7.4     67     5    1  2010    67       C
# 154  30.000000  193.000000   6.9     70     9   26  2010    70      PS
# 155  41.583333  145.000000  13.2     77     9   27  2010    77       S
# 156  14.000000  191.000000  14.3     75     9   28  2010    75       S
# 157  18.000000  131.000000   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
df["Weather"]=df["Weather"].fillna(df["Weather"].mode()[0])

# %%
del df['Temp C']

# %%
df
# Out:
#          Ozone     Solar.R  Wind Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4     5    1  2010    67       S
# 1    36.000000  118.000000   8.0     5    2  2010    72       C
# 2    12.000000  149.000000  12.6     5    3  2010    74      PS
# 3    18.000000  313.000000  11.5     5    4  2010    62       S
# 4    41.583333  185.403974  14.3     5    5  2010    56       S
# ..         ...         ...   ...   ...  ...   ...   ...     ...
# 153  41.000000  190.000000   7.4     5    1  2010    67       C
# 154  30.000000  193.000000   6.9     9   26  2010    70      PS
# 155  41.583333  145.000000  13.2     9   27  2010    77       S
# 156  14.000000  191.000000  14.3     9   28  2010    75       S
# 157  18.000000  131.000000   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df['Month'].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df[df['Month']=="May"]
# Out:
#     Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 23   32.0     92.0  12.0   May   24  2010    61       C

# %%
df["Month"] = df["Month"].replace("May", "5")

# %%
df['Month'].head(25)
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
# 5       5
# 6       5
# 7       5
# 8       5
# 9       5
# 10      5
# 11      5
# 12      5
# 13      5
# 14      5
# 15      5
# 16      5
# 17      5
# 18      5
# 19      5
# 20      5
# 21      5
# 22      5
# 23    May
# 24      5
# Name: Month, dtype: object

# %%
df[df['Month']=="May"]
# Out:
#     Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 23   32.0     92.0  12.0   May   24  2010    61       C

# %%
df['Month']=df['Month'].replace(to_replace="May",value=5)

# %%
df['Month'].head(25)
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# Name: Month, dtype: object

# %%
df["Month"]=df["Month"].astype(int)

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
# pd.to_numeric()

# %% [markdown]
# # Label Encoding
# # One hot Encoding

# %%
df_1=df.copy()

# %%
df_2=df.copy()

# %%
df_3=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_1["Weather"]=le.fit_transform(df_1["Weather"])

# %%
df_1
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0    41.000000  190.000000   7.4      5    1  2010    67        2
# 1    36.000000  118.000000   8.0      5    2  2010    72        0
# 2    12.000000  149.000000  12.6      5    3  2010    74        1
# 3    18.000000  313.000000  11.5      5    4  2010    62        2
# 4    41.583333  185.403974  14.3      5    5  2010    56        2
# ..         ...         ...   ...    ...  ...   ...   ...      ...
# 153  41.000000  190.000000   7.4      5    1  2010    67        0
# 154  30.000000  193.000000   6.9      9   26  2010    70        1
# 155  41.583333  145.000000  13.2      9   27  2010    77        2
# 156  14.000000  191.000000  14.3      9   28  2010    75        2
# 157  18.000000  131.000000   8.0      9   29  2010    76        0
#
# [158 rows x 8 columns]

# %%
df_1.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather      int32
# dtype: object

# %%
df_2
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4      5    1  2010    67       S
# 1    36.000000  118.000000   8.0      5    2  2010    72       C
# 2    12.000000  149.000000  12.6      5    3  2010    74      PS
# 3    18.000000  313.000000  11.5      5    4  2010    62       S
# 4    41.583333  185.403974  14.3      5    5  2010    56       S
# ..         ...         ...   ...    ...  ...   ...   ...     ...
# 153  41.000000  190.000000   7.4      5    1  2010    67       C
# 154  30.000000  193.000000   6.9      9   26  2010    70      PS
# 155  41.583333  145.000000  13.2      9   27  2010    77       S
# 156  14.000000  191.000000  14.3      9   28  2010    75       S
# 157  18.000000  131.000000   8.0      9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
OHE=OneHotEncoder()

# %%
import numpy as np

# %%
df_2[["Weather_c","Weather_ps","Weather_s",]]=OHE.fit_transform(df_2[["Weather"]]).toarray().astype("int")

# %%
df_2
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp Weather  Weather_c  \
# 0    41.000000  190.000000   7.4      5    1  2010    67       S          0
# 1    36.000000  118.000000   8.0      5    2  2010    72       C          1
# 2    12.000000  149.000000  12.6      5    3  2010    74      PS          0
# 3    18.000000  313.000000  11.5      5    4  2010    62       S          0
# 4    41.583333  185.403974  14.3      5    5  2010    56       S          0
# ..         ...         ...   ...    ...  ...   ...   ...     ...        ...
# 153  41.000000  190.000000   7.4      5    1  2010    67       C          1
# 154  30.000000  193.000000   6.9      9   26  2010    70      PS          0
# 155  41.583333  145.000000  13.2      9   27  2010    77       S          0
# 156  14.000000  191.000000  14.3      9   28  2010    75       S          0
# 157  18.000000  131.000000   8.0      9   29  2010    76       C          1
#
#      Weather_ps  Weather_s
# 0             0          1
# 1             0          0
# 2             1          0
# 3             0          1
# 4             0          1
# ..          ...        ...
# 153           0          0
# 154           1          0
# 155           0          1
# 156           0          1
# 157           0          0
#
# [158 rows x 11 columns]

# %%
df_3
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4      5    1  2010    67       S
# 1    36.000000  118.000000   8.0      5    2  2010    72       C
# 2    12.000000  149.000000  12.6      5    3  2010    74      PS
# 3    18.000000  313.000000  11.5      5    4  2010    62       S
# 4    41.583333  185.403974  14.3      5    5  2010    56       S
# ..         ...         ...   ...    ...  ...   ...   ...     ...
# 153  41.000000  190.000000   7.4      5    1  2010    67       C
# 154  30.000000  193.000000   6.9      9   26  2010    70      PS
# 155  41.583333  145.000000  13.2      9   27  2010    77       S
# 156  14.000000  191.000000  14.3      9   28  2010    75       S
# 157  18.000000  131.000000   8.0      9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df_3=pd.get_dummies(data=df_3,columns=["Weather"])

# %%
df_3
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp  Weather_C  \
# 0    41.000000  190.000000   7.4      5    1  2010    67      False
# 1    36.000000  118.000000   8.0      5    2  2010    72       True
# 2    12.000000  149.000000  12.6      5    3  2010    74      False
# 3    18.000000  313.000000  11.5      5    4  2010    62      False
# 4    41.583333  185.403974  14.3      5    5  2010    56      False
# ..         ...         ...   ...    ...  ...   ...   ...        ...
# 153  41.000000  190.000000   7.4      5    1  2010    67       True
# 154  30.000000  193.000000   6.9      9   26  2010    70      False
# 155  41.583333  145.000000  13.2      9   27  2010    77      False
# 156  14.000000  191.000000  14.3      9   28  2010    75      False
# 157  18.000000  131.000000   8.0      9   29  2010    76       True
#
#      Weather_PS  Weather_S
# 0         False       True
# 1         False      False
# 2          True      False
# 3         False       True
# 4         False       True
# ..          ...        ...
# 153       False      False
# 154        True      False
# 155       False       True
# 156       False       True
# 157       False      False
#
# [158 rows x 10 columns]

# %% [markdown]
# # Input
# ##  For Parametric model -- One hot encoding
# ##  For Non Parametric model-- Label Encoding

# %% [markdown]
# # Output
#
# ## Label Encoding

# %%
final=df_3

# %%
x=final.drop(labels="Temp",axis=1)

# %%
x
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Weather_C  Weather_PS  \
# 0    41.000000  190.000000   7.4      5    1  2010      False       False
# 1    36.000000  118.000000   8.0      5    2  2010       True       False
# 2    12.000000  149.000000  12.6      5    3  2010      False        True
# 3    18.000000  313.000000  11.5      5    4  2010      False       False
# 4    41.583333  185.403974  14.3      5    5  2010      False       False
# ..         ...         ...   ...    ...  ...   ...        ...         ...
# 153  41.000000  190.000000   7.4      5    1  2010       True       False
# 154  30.000000  193.000000   6.9      9   26  2010      False        True
# 155  41.583333  145.000000  13.2      9   27  2010      False       False
# 156  14.000000  191.000000  14.3      9   28  2010      False       False
# 157  18.000000  131.000000   8.0      9   29  2010       True       False
#
#      Weather_S
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
# ..         ...
# 153      False
# 154      False
# 155       True
# 156       True
# 157      False
#
# [158 rows x 9 columns]

# %%
y=final["Temp"]
y
# Out:
# 0      67
# 1      72
# 2      74
# 3      62
# 4      56
#        ..
# 153    67
# 154    70
# 155    77
# 156    75
# 157    76
# Name: Temp, Length: 158, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model=LogisticRegression()

# %%
model.fit(x,y)
# Out:
# C:\Users\mahit\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.80,shuffle=False,random_state=34)

# %%
y_train_pred=model.predict(x_train)

# %%
y_test_pred=model.predict(x_test)

# %%
accuracy_score(y_test,y_test_pred)
# Out:
# 0.125

# %%
accuracy_score(y_train,y_train_pred)
# Out:
# 0.12698412698412698

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
model_1=RandomForestRegressor()

# %%
model_1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.23493887170422734

# %%
r2_score(y_test,y_test_pred)
# Out:
# -0.2972375690607736
